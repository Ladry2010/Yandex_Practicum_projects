# %% [markdown]
# Привет, Наталия!
#
# Меня зовут Вячеслав Погорелый, и я буду проводить ревью твоего проекта.
#
# Предлагаю перейти на "ты", если не против)
#
# Но если это не удобно - дай знать, и мы перейдем на "вы". Моя главная задача — не находить сделанные тобою ошибки, а передать свой опыт и помочь тебе стать аналитиком данных.
#
# Я отметил комментарии и замечания разным цветом далее по тексту markdown:
#
# ---
# <div class="alert alert-block alert-danger">
#
# ### Ошибка
#
# Критическое замечание, которые следует исправить.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">
#
# ### Совет
#
# Замечание\совет на будущее.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">
#
# ### Успех
#
# Когда всё сделано правильно.
# </div>
#
#
#
# Будет здорово, если для ответов ты выберешь любой **<font color="maroon">читабельный и заметный цвет</font>**, так мне будет проще все проверить.
#
#
# При доработке проекта попрошу тебя сохранить и не видоизменять заметки ревьюера, это осложняет повторную проверку.

# %% [markdown]
# Постановка задачи : на основе имеющихся данных определить закономерности в продаже игр , сформулировать возможные рекомендаци на 2017 год.

# %% [markdown]
# Привет ,Вячеслав .Спасибо за хорошие слова о моем проекте. Старалась выполнить все рекомендации ,что получилось ,что то нет. Код по визуализации пропусков в тренажере не запустился.И не зна. ,как изменить шрифт и цвет в Юпитере.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# # Комментарий ревьюера ver.2
#
# #### Совет
#
# По поводу оформления в ячейках Маркдаун приодится эта статья https://translated.turbopages.org/proxy_u/en-ru.ru.cf754497-63cd7309-9a7f28e3-74722d776562/https/www.geeksforgeeks.org/markdown-cell-in-jupyter-notebook/

# %% [markdown]
# # 1.Подготовим данные к исследованию

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Давай тут добавим и оформим небольшое оглавление к проекту. Так он будет восприниматься лучше.

# %%
import pandas as pd

# %%
data = pd.read_csv('/datasets/games.csv')

# %%
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Здорово. Ты распаковала проект и сохранила его в переменную.

# %%
print(data.columns)#посмотрим названия колонок
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %%
data.columns = data.columns.str.lower()#приведем к нижнему регистру

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Классным методом привели к нижнему регистру.

# %%
print(data.columns)
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# А вот и первичную информацию мы получили.

# %%
data.isna().sum()#изучим пропуски
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Тут бы вывод результата сработал и без использования команды print(), поскольку это последняя строчка в ячейке кода.

# %% [markdown]
# ## Промежуточный вывод

# %% [markdown]
# Данные содержат пропуски в столбцах year_of_release,name ,genre,critic_score,user_score ,rating. Некоторые столбцы имеют неправильный тип данных :user_score,year_of_release

# %% [markdown]
# ### визуализация-код есть ,но у меня не запускается (

# %%
pip install missingno
import missngo as msno
msno.bar(data)
# Out:
#   File "/tmp/ipykernel_425/3602527196.py", line 1
#     pip install missingno
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### Комментарий ревьюера
#
# #### Ошибка
#
# Тут надо было оформить небольшой промежуточный вывод по итогу знакомства с данными.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Комментарий ревьюера ver.2
#
# #### Успех
#
# Вот теперь все отлично. Вывод на месте.
#
# А по поводу запуска библиотеки, так ты попробуй ее сперва установить в отдельной ячейке, а уже потом делать импорт.

# %%
data=data.dropna(subset=['year_of_release'])#кол-во строк с пропусками в столбце незначительно от общего кол-ва (16715),удалим

# %%
data=data.dropna(subset=['name','genre'])#всего по 2 строки с пропусками в столбце,можно удалить

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Логично. Пропусков мало и проще всего от них избавиться.

# %%
data['year_of_release'] = data['year_of_release'].astype('int')# год целое число ,переведем столбец в указанный тип

# %%
print(data['rating'].unique())# посмотрим уникальные значения столбца rating

# %% [markdown]
# Видим ,что есть пропуски. Земеним их на no "information"

# %%
data['rating'] = data['rating'].fillna(value='no information')

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# И здесь не могу поспорить.

# %%
print(data['rating'].value_counts())# посмотрим ,как они заменились

# %%
data

# %%
print(data.isna().sum())

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Рекомендую для визуализации пропусков использовать вот такую библиотеку https://russianblogs.com/article/5001266235/

# %% [markdown]
# Оставшиеся пропуски в двух колонках имеют большое кол-во .Удалять поэтому не будем,учтем в дальнейшем

# %%
data.info()

# %%
print(data['user_score'].value_counts())#посчитаем кол-ва уникальных значений по каждому рейтингу
# Out:
# tbd    2376
# 7.8     322
# 8       285
# 8.2     276
# 8.3     252
#        ...
# 0.7       2
# 9.6       2
# 0.2       2
# 9.7       1
# 0         1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# наибольшее кол-во у 'tbd'-'to be decided'(предстоит принять решение),оценки по пользователю еще нет ,можем заменить на пустое значение 'Nan'

# %%
data.loc[data['user_score']=='tbd','user_score']='NaN'

# %%
print(data['user_score'].value_counts())#проверим замену
# Out:
# NaN    2376
# 7.8     322
# 8       285
# 8.2     276
# 8.3     252
#        ...
# 0.7       2
# 9.6       2
# 0.2       2
# 9.7       1
# 0         1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# Теперь можно поменять тип столбца на числовой

# %%
data['user_score'] = data['user_score'].astype(float,errors='ignore')

# %%
data.info()

# %% [markdown]
# Оставшиеся типы столбцов вполне соответствуют своим значениям

# %%
print(data.duplicated().sum())# проверим на явные дубликаты
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Здорово, дублей у нас не оказалось.

# %% [markdown]
# Проверим на неявные дубликаты ,название игр могут быть записаны с большой и маленькой буквы .Приведем все к нижнему регистру.

# %%
data['name'].str.lower()#
# Out:
# 0                           wii sports
# 1                    super mario bros.
# 2                       mario kart wii
# 3                    wii sports resort
# 4             pokemon red/pokemon blue
#                      ...
# 16710    samurai warriors: sanada maru
# 16711                 lma manager 2007
# 16712          haitaka no psychedelica
# 16713                 spirits & spells
# 16714              winning post 8 2016
# Name: name, Length: 16444, dtype: object

# %%
print(data.duplicated().sum())#новые дубликаты не появились
# Out:
# 0

# %% [markdown]
# Добавим столбец общих продаж в нашу таблицу

# %%
data['sum_sales'] = data['na_sales']+data['eu_sales']+data['jp_sales']+data['other_sales']# добавим столбец общих продаж в таблицу

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# А еще можешь такой метод использовать df['x'] = df[['a', 'b', 'c']].sum()

# %% [markdown]
# # Вывод

# %% [markdown]
# Данные подготовлены к дальнейшим исследованиям: убрали пропуски ,которые было возможно ,изменили необходимы типы данных,объединили данные по продаж в регионах в единый столбец

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### Комментарий ревьюера
#
# #### Ошибка
#
# Тут тоже промежуточный вывод нужен после Предобработки.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Комментарий ревьюера ver.2
#
# #### Успех
#
# Теперь другое дело

# %% [markdown]
# # 2 Исследование данных

# %%
data

# %% [markdown]
# Посмотрим, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
print(data.groupby('year_of_release')['name'].count())
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     829
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1197
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     653
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# Name: name, dtype: int64

# %%
(data
     .pivot_table(index='year_of_release', values='name', aggfunc='count')
     .sort_values(by='year_of_release')
     .plot(title='Продажа игр по годам ',grid=True,figsize=(12,5))
)
# Out:
# <AxesSubplot:title={'center':'Продажа игр по годам '}, xlabel='year_of_release'>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Может давай тут график выведем? Так результат будет восприниматься намного лучше.

# %% [markdown]
# Продажи игр выросли в "нулевых".Учтем в дальнейших исследованиях

# %% [markdown]
# Посмотрим, как менялись продажи по платформам. Выберем платформы с наибольшими суммарными продажами и построим распределение по годам

# %%
(data
     .pivot_table(index='platform',values='sum_sales',aggfunc='median')
     .sort_values(by='sum_sales',ascending=False)
   
)
# Out:
#           sum_sales
# platform
# NES           1.375
# GB            1.180
# 2600          0.480
# SNES          0.320
# X360          0.280
# PS3           0.280
# N64           0.270
# PS            0.260
# PS2           0.230
# XOne          0.220
# WiiU          0.220
# WS            0.215
# PS4           0.200
# Wii           0.190
# GBA           0.160
# XB            0.150
# GEN           0.150
# GC            0.150
# DC            0.135
# SAT           0.120
# 3DS           0.120
# DS            0.110
# NG            0.100
# PSP           0.090
# TG16          0.080
# SCD           0.065
# PSV           0.050
# PC            0.050
# GG            0.040
# PCFX          0.030
# 3DO           0.020

# %%
#print(data.groupby('platform')['sum_sales'].median())

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Ну и тут взглянули на лидеров по платформам.

# %%
names = ['NES','GB','NES','2600','SNES']

# %%
for name in names:
    new_data = data[data['platform']==name]
    (new_data   
             .pivot_table(index='year_of_release',values='sum_sales')
             .plot(kind='bar',cmap='RdYlBu',title=('Продажи на платформе {} по годам').format(name),grid=True,figsize=(12,5))
    )

# %%
(data.query('platform=="NES"')
    .pivot_table(index='year_of_release',values='sum_sales')
    .plot(kind='bar',title='Продажи на платформе NES  по годам',grid=True,figsize=(12,5))
)
# Out:
# <AxesSubplot:title={'center':'Продажи на платформе NES  по годам'}, xlabel='year_of_release'>

# %%
(data.query('platform=="GB"')
    .pivot_table(index='year_of_release',values='sum_sales')
    .plot(kind='bar',title='Продажи на платформе GB  по годам',grid=True,figsize=(12,5))
)
# Out:
# <AxesSubplot:title={'center':'Продажи на платформе GB  по годам'}, xlabel='year_of_release'>

# %%
(data.query('platform=="2600"')
    .pivot_table(index='year_of_release',values='sum_sales')
    .plot(kind='bar',title='Продажи на платформе 2600  по годам',grid=True,figsize=(12,5))
)
# Out:
# <AxesSubplot:title={'center':'Продажи на платформе 2600  по годам'}, xlabel='year_of_release'>

# %%
(data.query('platform=="SNES"')
    .pivot_table(index='year_of_release',values='sum_sales')
    .plot(kind='bar',title='Продажи на платформе SNES  по годам',grid=True,figsize=(12,5))
)
# Out:
# <AxesSubplot:title={'center':'Продажи на платформе SNES  по годам'}, xlabel='year_of_release'>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Отлично получилось. В идеале эти графики можно было вывести автоматом через цикл.

# %% [markdown]
# Четыре платформы с максимальными продажами прекратили свое существование, поэтому максимальные продажи в прошлом важны для истории,но не для прогнозирования дальнейших продаж.

# %%
#print(data.groupby('year_of_release')['platform'].count())

# %% [markdown]
# Посмотрим продажи на всех платформах

# %%
(data
     .pivot_table(index='year_of_release',columns='platform',values='sum_sales',aggfunc='median')
     .plot(title='Продажи на платформах по годам',figsize=(20, 15))
)
# Out:
# <AxesSubplot:title={'center':'Продажи на платформах по годам'}, xlabel='year_of_release'>

# %% [markdown]
# Платформы живут от 5 до 10 лет ,посмотрим на года ,когда выросли продажи игр

# %%
(data.query('year_of_release>=2002')
     .pivot_table(index='year_of_release',columns='platform',values='sum_sales',aggfunc='median')
     .plot(title='Продажи на платформах 2002-2016',figsize=(20, 10))
)
# Out:
# <AxesSubplot:title={'center':'Продажи на платформах 2002-2016'}, xlabel='year_of_release'>

# %% [markdown]
# Видно , что к 2012 году многие платформы перестали существовать ,в то же время появились новые ,посмотрим какие их них будет перспективны на 2017 год Выбираем актуальный период с 2012по 2016 год

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Все верно. В такой перспективно сфере как видеоигры, незачем смотреть на очеь старые данные.

# %%
(data.query('year_of_release>=2012')
     .pivot_table(index='year_of_release',columns='platform',values='sum_sales',aggfunc='median')
     .plot(title='Продажи на платформах 2012-2016',figsize=(10, 7))
)
# Out:
# <AxesSubplot:title={'center':'Продажи на платформах 2012-2016'}, xlabel='year_of_release'>

# %%
(data
    .query('year_of_release>=2012')
    .pivot_table(index='platform',columns='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',grid=True,title='Продажи на платформах в c 2012 по 2016',figsize=(12, 9))
)
# Out:
# <AxesSubplot:title={'center':'Продажи на платформах в c 2012 по 2016'}, xlabel='platform'>

# %% [markdown]
# Рассмотрим подробнее продажи по платформам,попавшие в актуальный период за все время их существования

# %%
(data.query('platform=="Wii"')#Nintendo
    .pivot_table(index='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',title='Платформа Wii',grid=True,figsize=(12,3))
)
# Out:
# <AxesSubplot:title={'center':'Платформа Wii'}, xlabel='year_of_release'>

# %% [markdown]
# Платформа прошла свой пик в 2014 ,после которого был спад и сейчас подъем. Достаточно равномерные продажи и ,хотя ей уже 10 лет ,можно порекомендовать на 2017 год

# %%
(data.query('platform=="WiiU"')#Nintendo
    .pivot_table(index='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',title='Платформа WiiU',grid=True,figsize=(7,3))
)
# Out:
# <AxesSubplot:title={'center':'Платформа WiiU'}, xlabel='year_of_release'>

# %% [markdown]
# Платформа молодая -5 лет ,популярность стабильная ,падение было в 2014 году ,сейчас продажи вернулись +-. Может быть использована в 2017 году

# %%
(data.query('platform=="XOne"')
    .pivot_table(index='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',title='Платформа XOne',grid=True,figsize=(7,3))
)
# Out:
# <AxesSubplot:title={'center':'Платформа XOne'}, xlabel='year_of_release'>

# %% [markdown]
# Платформа идет на спад ,пик был в начале,в 2013 году(возможно это связано с общим падением рынка ,что видно по кол-ву проданных игр ).Но платформа всего существует 4 года ,поэтому перспективы в продажах на 2017 год есть

# %%
(data.query('platform=="3DS"')#Nintendo портативная
    .pivot_table(index='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',title='Платформа 3DS',grid=True,figsize=(7,3))
)
# Out:
# <AxesSubplot:title={'center':'Платформа 3DS'}, xlabel='year_of_release'>

# %% [markdown]
# Пик был в 2012 году ,продажи стабильны , может быть еще актуальна на 2017 год

# %%
(data.query('platform=="PSV"')# PlayStation портативная ,преемник PSP
    .pivot_table(index='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',title='Платформа PSV',grid=True,figsize=(5,5))
)
# Out:
# <AxesSubplot:title={'center':'Платформа PSV'}, xlabel='year_of_release'>

# %% [markdown]
# Платформа имеет стабильные продажи ,рекомендована на 2017 год

# %%
(data.query('platform=="PS4"')# PlayStation 4
    .pivot_table(index='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',title='Платформа PS4',grid=True,figsize=(5,5))
)
# Out:
# <AxesSubplot:title={'center':'Платформа PS4'}, xlabel='year_of_release'>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# И вновь по графикам хорошо вышло.

# %% [markdown]
# Продажи на платформе меньше(но возможно данные за 2016 год не полные) ,чем при создании ,но они больше ,чем у предшественницы PlayStation 3,поэтому платформа остается перспективной на 2017 год

# %%
(data.query('platform=="PC"')# 
    .pivot_table(index='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',title='Платформа PC',grid=True,figsize=(12,7))
)
# Out:
# <AxesSubplot:title={'center':'Платформа PC'}, xlabel='year_of_release'>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Давай ты графикам будешь давать названия. Так сразу будет понятно, что ты на них пытаешься показать.

# %% [markdown]
# Игры на персональном компьютере были наиболее продаваемы в 90-х,но сейчас тоже имеют стабильные продажи , в следущем году предполагаю,что это сохранится.

# %%
(data.query('platform=="PS3"')# PlayStation 3
    .pivot_table(index='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',title='Платформа PS3',grid=True,figsize=(12,5))
)
# Out:
# <AxesSubplot:title={'center':'Платформа PS3'}, xlabel='year_of_release'>

# %% [markdown]
# Выпущена следущая версия ,но PS3 еще выпускается,продажи стабильны, и может вполне продаваться в 2017 году

# %%
(data.query('platform=="X360"')
    .pivot_table(index='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',title='Платформа X360',grid=True,figsize=(12,5))
)
# Out:
# <AxesSubplot:title={'center':'Платформа X360'}, xlabel='year_of_release'>

# %% [markdown]
# Платформа уже 10 лет,пики продаж 2008 ,2012 и 2013. Сейчас тренд платформы -спад продаж (в 2016 прекращено производство ). На 2017 год не рекомендую

# %%
(data.query('platform=="PSP"')#	PlayStation портативная
    .pivot_table(index='year_of_release',values='sum_sales',aggfunc='median')
    .plot(kind='bar',title='Платформа PSP',grid=True,figsize=(12,5))
)
# Out:
# <AxesSubplot:title={'center':'Платформа PSP'}, xlabel='year_of_release'>

# %% [markdown]
# Платформа работает больше 10 лет. Пик прошла через год после создания в 2005 году.А также незначительный пик в 2008 .Последнии годы устойчивый спад продаж.Не рекомендую на 2017 год

# %% [markdown]
# # platform_top

# %%
platform_top = ['Wii','WiiU','XOne','PS4','PSV','3DS','PC','PS3']

# %%
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
data.boxplot(column=['sum_sales'],by=['platform'],figsize=(20, 20)) 
#plt.ylim(-0.5, 20)
#plt.xlim (0,30)
# Out:
# <AxesSubplot:title={'center':'sum_sales'}, xlabel='[platform]'>

# %% [markdown]
# # data_actual:

# %%
data_actual = data.query('year_of_release>=2012')# делаем срез по актуальному периоду

# %% [markdown]
# посмотрим распределение продаж по платформам из platform_top за актуальный период

# %%
import matplotlib.pyplot as plt

(data_actual.query('platform in @platform_top')
       .boxplot(column=['sum_sales'],by=['platform'],figsize=(20, 20))
)              
plt.ylim(0, 2)
#plt.xlim (0,30)
# Out:
# (0.0, 2.0)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# А вот здесь отдельно хочу похвалить за то, что тобой ограничены выбросы на графике.

# %% [markdown]
# На диаграмме рассеяния можно посмотреть по каждой платформе ,где заканчивается нормальное распределение-туда упирается"ус" (дальше выбросы ,которые мы частично отсекли). Расположние 1 квантиля -ниже него 25% всех значений ,медианы ( 50%),3 квантиля ,ниже которого 75% значений.

# %% [markdown]
# Практически на каждой платформе распределение продаж неравномерное,так продажи игр зависят не только от выбранной платформы ,но и от жанра

# %% [markdown]
# Посмотрим, как влияют на продажи внутри одной популярной платформы WiiU отзывы пользователей и критиков. Построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами.

# %%
data_wi = data_actual.query('platform=="WiiU"')#построим срез данных по этой платформе
print(data_wi['critic_score'].corr(data_wi['sum_sales']))
# Out:
# 0.34837976012017485

# %%
data_wi.plot(x='critic_score',y='sum_sales',kind='scatter',title='Зависимость общих продаж от отзывов критиков WiiU',figsize=(8, 7))
# Out:
# <AxesSubplot:title={'center':'Зависимость общих продаж от отзывов критиков WiiU'}, xlabel='critic_score', ylabel='sum_sales'>

# %% [markdown]
# Зависимость не высокая ,коэфф-т и график это показывают.Продажи незначительно увеличиваются при высоких оценках критиков ,но значительное увеличение наблюдается в еденичных случаях

# %% [markdown]
# Посмотрим еще одну популярную платформу PS4

# %%
data_ps4 = data_actual.query('platform=="PS4"')#построим срез данных по этой платформе
print(data_ps4['critic_score'].corr(data_ps4['sum_sales']))
# Out:
# 0.40656790206178095

# %%
data_ps4.plot(x='critic_score',y='sum_sales',kind='scatter',title='Зависимость общих продаж от отзывов критиков PS4 ',figsize=(8, 7))
# Out:
# <AxesSubplot:title={'center':'Зависимость общих продаж от отзывов критиков PS4 '}, xlabel='critic_score', ylabel='sum_sales'>

# %%
print(data_actual['critic_score'].corr(data_actual['sum_sales']))#посчитаем коэфф-т корреляции для всех платформ
# Out:
# 0.3081967459207781

# %% [markdown]
# По всем платформам этот показатель еще ниже

# %% [markdown]
# Посмотрим зависимости продаж от оценок пользователей для двух популярных платформ

# %%
print(data_wi['user_score'].corr(data_wi['sum_sales']))#коэфф-т корреляции общих продаж от отзывов пользователей
# Out:
# 0.4002190202148617

# %%
data_wi.plot(x='user_score',y='sum_sales',kind='scatter',title='Зависимость общих продаж от отзывов пользователей ',figsize=(8, 7))
# Out:
# <AxesSubplot:title={'center':'Зависимость общих продаж от отзывов пользователей '}, xlabel='user_score', ylabel='sum_sales'>

# %%
print(data_ps4['user_score'].corr(data_ps4['sum_sales']))
# Out:
# -0.031957110204556376

# %% [markdown]
# Коэфф-т очень маленький ,за счет выбросов на низких значениях оценки даже отрицательный

# %%
data_ps4.plot(x='user_score',y='sum_sales',kind='scatter',title='Зависимость общих продаж от отзывов пользователей PS4',figsize=(8, 7))
# Out:
# <AxesSubplot:title={'center':'Зависимость общих продаж от отзывов пользователей PS4'}, xlabel='user_score', ylabel='sum_sales'>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Классный график вышел для показа зависимости.

# %% [markdown]
# В целом можно сказать :зависимость не высокая .Продажи незначительно увеличиваются при высоких оценках критиков ,но значительное увеличение наблюдается в еденичных случаях

# %%
print(data['user_score'].corr(data['sum_sales']))# по всем платформам
# Out:
# 0.08798399271321647

# %% [markdown]
# В целом можно заключить ,что продажи от мнения критиков и пользователей зависят ,но не сильно. Думаю ,на более новых платформах их мнения важнее.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### Комментарий ревьюера
#
# #### Ошибка
#
# Тут надо рассмотреть зависимость хотя бы еще для одной платформы. Так выводы были бы намного убедительнее.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Комментарий ревьюера ver.2
#
# #### Успех
#
# Вот так выводы кажутся более обоснованными.

# %%
#print(data.groupby('genre')['name'].count())

# %%
print(data['genre'].value_counts())
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: genre, dtype: int64

# %%
(data
    
    .pivot_table(index='genre',values='sum_sales',aggfunc='median')
    .plot(kind='bar',grid=True,title='Продажи игр по жанрам',figsize=(10, 7))
)
# Out:
# <AxesSubplot:title={'center':'Продажи игр по жанрам'}, xlabel='genre'>

# %% [markdown]
# Посмотрим продажу по жанрам в долях за актуальный период

# %%
import matplotlib.pyplot as plt
(data_actual
    
    .pivot_table(index='genre',values='sum_sales',aggfunc='median')
    .plot.pie(y='sum_sales',cmap='tab20b',title='Продажи игр по жанрам',figsize=(8, 8))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### Комментарий ревьюера
#
# #### Ошибка
#
# Давай тут подправим график и сделаем так, чтобы легенда не наползала на сам график.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Комментарий ревьюера ver.2
#
# #### Успех
#
# Супер

# %% [markdown]
# Самые популярный жанр -Shoter ("стрелялки "),дальше идут Platform и Sports. В целом наименьший спрос у игр жанра Adventure и Puzzle

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Тобой верно определен самый прибыльный жанр. Тут надо именно на медианные или средние продажи смотреть.

# %% [markdown]
# Определим  для пользователя каждого региона (NA, EU, JP):
# Самые популярные платформы (топ-5). Опишим различия в долях продаж.

# %%
(data_actual
     .pivot_table(index='platform',values='na_sales',aggfunc='median')
     .sort_values(by='na_sales',ascending=False)
     
)
# Out:
#           na_sales
# platform
# X360         0.170
# XOne         0.120
# WiiU         0.110
# PS4          0.060
# PS3          0.050
# Wii          0.045
# 3DS          0.000
# DS           0.000
# PC           0.000
# PSP          0.000
# PSV          0.000

# %%
platform_5 = ['X360','XOne','WiiU','PS4','Wii']# ТОП-5 самых продаваемых платформ

# %%
(data_actual
     .query('platform in @platform_5')
     .pivot_table(index='platform',values='na_sales',aggfunc='median')     
     .plot.pie(y='na_sales',normalize=True,cmap='plasma',figsize=(5, 5))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %% [markdown]
# Наиболее продаваемы игры на платформах XOne  и предшественница X360 .И то и другое продукция компании Microsoft. Штаб квартира в США ,поэтому наиболее активная реклама здесь ,отсюда и популярность.

# %%
(data_actual
     .pivot_table(index='genre',values='na_sales',aggfunc='median')
     .sort_values(by='na_sales',ascending=False)
     
)
# Out:
#               na_sales
# genre
# Shooter           0.20
# Platform          0.09
# Sports            0.08
# Fighting          0.05
# Racing            0.04
# Action            0.02
# Role-Playing      0.02
# Misc              0.01
# Adventure         0.00
# Puzzle            0.00
# Simulation        0.00
# Strategy          0.00

# %%
genre_5_na = ['Shooter','Platform','Sports','Fighting','Racing']#ТОП -

# %%
(data_actual
     .query('genre in @genre_5_na')
     .pivot_table(index='genre',values='na_sales',aggfunc='median')     
    .plot.pie(y='na_sales',cmap='plasma',normalize=True,figsize=(5, 5))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %% [markdown]
# *А можно показать это так ,распределение продаж по жанрам*

# %%
import seaborn as sns
plt.figure(figsize=(15,8))
plt.ylim(0,1.2)
sns.boxplot(data=data_actual,x='genre',y='na_sales',order=['Shooter','Platform','Sports','Fighting','Racing'])
# Out:
# <AxesSubplot:xlabel='genre', ylabel='na_sales'>

# %% [markdown]
# Лидируют "стрелялки ".Возможно из-за того ,что свободное ношение оружия разрешено в большинстве штатов.Достаточно популярны Platform и Sports

# %%
(data_actual
    
    .pivot_table(index='rating',values='na_sales',aggfunc='median')
    .plot(kind='bar',grid=True,cmap='viridis',title='Продажи игр в зависимости от рейтинга',figsize=(5, 5))
)
# Out:
# <AxesSubplot:title={'center':'Продажи игр в зависимости от рейтинга'}, xlabel='rating'>

# %% [markdown]
# В зависимости от рейтинга  ESRB наиболее популярны игры для взрослых с маркировкой М,достаточно популярны игры для детей старше 10 лет.

# %%
(data_actual
     .pivot_table(index='platform',values='eu_sales',aggfunc='median')
     .sort_values(by='eu_sales',ascending=False)
     
)
# Out:
#           eu_sales
# platform
# X360          0.10
# PS4           0.08
# WiiU          0.07
# XOne          0.07
# PC            0.06
# Wii           0.04
# PS3           0.03
# DS            0.02
# 3DS           0.00
# PSP           0.00
# PSV           0.00

# %%
platform_5_eu = ['X360','PS4','WiiU','XOne','PC']

# %%
(data_actual
     .query('platform in @platform_5_eu')
     .pivot_table(index='platform',values='eu_sales',aggfunc='median')     
     .plot.pie(y='eu_sales',cmap='rainbow',normalize=True,figsize=(5, 5))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %% [markdown]
# Успех платформ практически одинаков .Европейцам нравится в большей степени продукция Microsoft,PlayStation и  Nintendo занимают одинаковые позиции. Хочется отметить ,что в Европе также популярны компьютерные игры.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Первое представление о регионах получили. Отлично.

# %%
(data_actual
     .pivot_table(index='genre',values='eu_sales',aggfunc='median')
     .sort_values(by='eu_sales',ascending=False)
     
)
# Out:
#               eu_sales
# genre
# Shooter          0.170
# Racing           0.090
# Platform         0.080
# Sports           0.050
# Simulation       0.030
# Action           0.020
# Fighting         0.020
# Misc             0.015
# Puzzle           0.010
# Role-Playing     0.010
# Strategy         0.010
# Adventure        0.000

# %%
genre_5_eu = ['Shooter','Platform','Sports','Simulation','Racing']
(data_actual
     .query('genre in @genre_5_eu')
     .pivot_table(index='genre',values='eu_sales',aggfunc='median')     
    .plot.pie(y='eu_sales',cmap='rainbow',normalize=True,figsize=(5, 5))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %% [markdown]
# На первом месте с большим отрывом Shooter,второе разделили Platform и Racing .Меньше всего Simulation

# %%
(data_actual
    
    .pivot_table(index='rating',values='eu_sales',aggfunc='median')
    .plot(kind='bar',grid=True,cmap='summer',title='Продажи игр в зависимости от рейтинга',figsize=(5, 5))
)
# Out:
# <AxesSubplot:title={'center':'Продажи игр в зависимости от рейтинга'}, xlabel='rating'>

# %% [markdown]
#  в зависимости от рейтинга  ESRB наиболее продаваемы игры с маркировкой М-для взрослых

# %%
(data_actual
     .pivot_table(index='platform',values='jp_sales',aggfunc='median')
     .sort_values(by='jp_sales',ascending=False)
     
)
# Out:
#           jp_sales
# platform
# 3DS           0.06
# PS3           0.03
# PSP           0.03
# PSV           0.03
# PS4           0.01
# DS            0.00
# PC            0.00
# Wii           0.00
# WiiU          0.00
# X360          0.00
# XOne          0.00

# %%
 platform_5_jp = ['3DS','PS3','PSP','PSV','PS4']

# %%
(data_actual
     .query('platform in @platform_5_jp')
     .pivot_table(index='platform',values='jp_sales',aggfunc='median')     
     .plot.pie(y='jp_sales',cmap='RdYlBu',normalize=True,figsize=(5, 5))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %% [markdown]
# Nintendo и PlayStation всех видов. Вот что покупают в Японии,так обе компании японские и свой рынок похоже полностью ими завоеван.

# %%
(data_actual
     .pivot_table(index='genre',values='jp_sales',aggfunc='median')
     .sort_values(by='jp_sales',ascending=False)
     
)
# Out:
#               jp_sales
# genre
# Role-Playing      0.06
# Fighting          0.03
# Misc              0.02
# Action            0.01
# Adventure         0.01
# Platform          0.00
# Puzzle            0.00
# Racing            0.00
# Shooter           0.00
# Simulation        0.00
# Sports            0.00
# Strategy          0.00

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Тут мы видим, что Япония наиболее уникальна среди всех регионов.

# %%
genre_5_jp = ['Role-Playing','Fighting','Misc','Action','Adventure']
(data_actual
     .query('genre in @genre_5_jp')
     .pivot_table(index='genre',values='jp_sales',aggfunc='median')     
    .plot.pie(y='jp_sales',cmap='RdYlBu',normalize=True,figsize=(5, 5))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %% [markdown]
# Японский рынок очень отличется в предпочтениях по жанрам от двух предыдущих .Почти половину занимают Role-Playing

# %% [markdown]
# Влияет ли рейтинг ESRB на продажи в Японии

# %%
(data_actual
    
    .pivot_table(index='rating',values='jp_sales',aggfunc='median')
    .plot(kind='bar',grid=True,cmap='RdYlBu',title='Продажи игр в зависимости от рейтинга',figsize=(5, 5))
)
# Out:
# <AxesSubplot:title={'center':'Продажи игр в зависимости от рейтинга'}, xlabel='rating'>

# %% [markdown]
# рейтинг  ESRB распространен в США и КАнаде,в Японии этот рейтинг не обязателен. Обязателен свой рейтинг CERO

# %%
#data_XboxOne = data.query('platform=="XOne"')
#data_PC = data.query('platform=="PC"')

# %% [markdown]
# ### Проверим гипотезу-Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# **H_0 :Средний пользовательский рейтинг платформы Xbox One равен среднему рейтингу платформы PC
# H_a: Средний пользовательский рейтинг платформы Xbox One не равен среднему рейтингу платформы PC
# alpha = 0.05**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Гипотезы сформулированы. Супер.

# %%
from scipy import stats as st

import numpy as np
                     

alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу

results = st.ttest_ind(
    data[(data['platform'] =='XOne')&(data['user_score'].notnull())]['user_score'],# results = вызов метода для проверки гипотезы
    data[(data['platform'] =='PC')&(data['user_score'].notnull())]['user_score'],
    equal_var = False)    

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 4.5385802963771835e-06
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Метод проверки определен верно. С выводами соглашусь.

# %% [markdown]
# ### Вывод -Средние пользовательские рейтинги платформ Xbox One и PC разные

# %% [markdown]
# ### Проверим гипотезу -Средние пользовательские рейтинги жанров Action и Sports  разные.

# %% [markdown]
# **H_0 :Средний пользовательский рейтинг жанра Action  равен среднему рейтингу жанра Sports
# H_a:Средний пользовательский рейтинг жанра Action не равен среднему рейтингу жанра Sports**

# %%
from scipy import stats as st

import numpy as np
                     

alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу

results = st.ttest_ind(
    data[(data['genre'] =='Action')&(data['user_score'].notnull())]['user_score'],
    data[(data['genre'] =='Sports')&(data['user_score'].notnull())]['user_score'],
    equal_var = False)    

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.07370217419278526
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# ### Вывод : гипотеза не верна , рейтинги равны

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# И тут здорово.

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе исследования продаж компьютерных игр за указанный период было установлено ,что тренд меняется очень быстро,платформы на которых выпускают игры живут  от  5 до 10 лет. Исключение составляют игры на PC . Максиму продаж пришелся на 90-ые ,дальше развивался рынок консолей. Проиллюстрируем графиком ,как появлялись и исчезали платформы.

# %%
(data
     .pivot_table(index='year_of_release',columns='platform',values='sum_sales',aggfunc='median')
     .plot(title='Продажи на платформах по годам',figsize=(15, 7))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %%
(data
     .pivot_table(index='year_of_release', values='name', aggfunc='count')
     .sort_values(by='year_of_release')
     .plot(title='Продажа игр по годам ',grid=True,figsize=(12,5))
)
# Out:
# <AxesSubplot:title={'center':'Продажа игр по годам '}, xlabel='year_of_release'>

# %% [markdown]
# Продажи компьютерных игр непрерывно росли ,пик пришелся на середину "нулевых" ,дальше произошел спад с приходом эры смартфонов,но тем не менне рынок игр по прежнему актуален.

# %% [markdown]
# В ходе исследований был определен актуальный период  и рассмотрены продажи на популярных платформах

# %% [markdown]
# На диаграмме размаха ,по выбранным платформам мы видим выбросы в данных,они в виде точек.Выбросы могли получиться из-за ошибок записи в данных (лишний ноль или "." в неправильном месте )

# %%
import matplotlib.pyplot as plt

(data_actual.query('platform in @platform_top')
       .boxplot(column=['sum_sales'],by=['platform'],figsize=(20, 20))
)              
plt.ylim(0, 2)
#plt.xlim (0,30)
# Out:
# (0.0, 2.0)

# %% [markdown]
# Для более точного расчета продаж по платформам лучше ограничиться данными ,не выходящими за верхний "ус" нормального распределения(видно на графике ),тогда расчеты будут более достоверными.

# %% [markdown]
# На основе проведенных исследований ,проведенных за актуальный период с 2012-2016 года, рекомендованы на 2017 год следущие платформы .Платформы представлены в долях по объему продаж за указанные годы.

# %%
(data_actual.query('platform in @platform_top')
    
    .pivot_table(index='platform',values='sum_sales',aggfunc='median')
    .plot.pie(y='sum_sales',grid=True,title='Продажи на платформах ',figsize=(10, 7))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %% [markdown]
# **Наиболее распространенный жанр SHooter , далее идут Platform и Sports**

# %%
(data_actual
    
    .pivot_table(index='genre',values='sum_sales',aggfunc='median')
    .plot.pie(y='sum_sales',title='Продажи игр по жанрам',figsize=(10, 7))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %% [markdown]
# **Но есть нюансы по регионам :**

# %% [markdown]
# **Северная Америка: потребители больше склоняются к продукции Microsoft(из показанных выше) .По жанрам:**

# %%
(data_actual
     .query('genre in @genre_5_na')
     .pivot_table(index='genre',values='na_sales',aggfunc='median')     
    .plot.pie(y='na_sales',normalize=True,figsize=(5, 5))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %%
Европа : больше Microsoft ,но также в равной степени представлены PlayStation ,  Nintendo ,компьютерные игры

# %%
genre_5_eu = ['Shooter','Platform','Sports','Simulation','Racing']
(data_actual
     .query('genre in @genre_5_eu')
     .pivot_table(index='genre',values='eu_sales',aggfunc='median')     
    .plot.pie(y='eu_sales',normalize=True,figsize=(5, 5))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %%
Япония : продукция PlayStation и  Nintendo .А по жанрам:

# %%
genre_5_jp = ['Role-Playing','Fighting','Misc','Action','Adventure']
(data_actual
     .query('genre in @genre_5_jp')
     .pivot_table(index='genre',values='jp_sales',aggfunc='median')     
    .plot.pie(y='jp_sales',normalize=True,figsize=(5, 5))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %%
genre_5_jp = ['Role-Playing','Fighting','Misc','Action','Adventure']
(data_actual
     .query('genre in @genre_5_jp')
     .pivot_table(index='genre',values='jp_sales',aggfunc='median')     
    .plot.pie(y='jp_sales',normalize=True,figsize=(5, 5))
)
plt.legend(bbox_to_anchor=( 1.05 , 1 ), loc='upper left', borderaxespad= 0 )

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.subplot(1,3,1)
data_actual.groupby('platform')['na_sales'].sum().sort_values(ascending=False).head()\
.plot(kind='pie',subplots=True,cmap='cividis',figsize=(20,10),autopct='%.0f%%')
plt.subplot(1,3,2)
data_actual.groupby('platform')['eu_sales'].sum().sort_values(ascending=False).head()\
.plot(kind='pie',subplots=True,cmap='autumn',figsize=(20,10),autopct='%.0f%%')
plt.subplot(1,3,3)
data_actual.groupby('platform')['jp_sales'].sum().sort_values(ascending=False).head()\
.plot(kind='pie',subplots=True,cmap='tab20b',figsize=(20,10),autopct='%.0f%%')
#fig=plt.figure(figsize=(10,10))
#plt.figure(figsize=(10,10))
plt.rcParams ['figure.figsize'] = [20, 20]

plt.show()

# %% [markdown]
# исследования показали ,что продажи от отзывов критиков и пользователй зависят мало ( Видимо реклама действует сильнее),а рейтинг ESRB имеет значение только в Европе и Северной Америке (в Японии он свой)

# %% [markdown]
# В целом хочется сказать ,что рынок копьютерных игр динамичен. Необходимо учитывать регион продаж и следить за новинками производителей Microsoft, Sony ,Nintendo.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### Комментарий ревьюера
#
# #### Ошибка
#
# А вот здесь хотелось бы более развернутый вывод увидеть вместе с рекомендациями. У тебя достаточно большой проект и хотелось бы больше инсайтов увидеть. Плюс в данных есть выбросы. Что бы ты рекомендовала сделать, чтобы минимизировать выбросы в другой раз?

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Комментарий ревьюера ver.2
#
# #### Успех
#
# Сейчас с таким выводом не стыдно идти к заказчику. Здорово.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Итоговый комментарий ревьюера
#
# #### Успех
#
# Спасибо тебе за проделанную работу. У тебя, определенно, есть хорошая база, при помощи который ты здорово справилась с работой. Отдельно хочу похвалить за работу с графиками. Отдельного внимания заслуживает раздел по проверке Гипотез и Предобработке данных. А еще работа логична и последовательна.
#
# Но в проекте есть замечания, которые надо будет поправить:
#
# * Добавить промежуточный выводы.
# * Добавить исследование зависимости оценок хотя бы еще для одной платформы.
# * Исправить легенду на круговой диаграмме при исследовании регионов.
# * Доработать итоговый вывод.
#
#
# А еще, я оставил в работе рекомендации. Надеюсь, они тебе помогут в дальнейшем.
#
# Буду ждать проект после доработок. Удачи.
# </div

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Итотоговый Комментарий ревьюера ver.2
#
# #### Успех
#
# Спасибо тебе за доработку проекта. Теперь я его принимаю и желаю тебе успехов в дальнешей учебе. Ты точно справишься, я уверен:)
